# %% [markdown]
# ## Testen ob Claude API funktioniert

# %%
from dotenv import load_dotenv # um api von .env zu laden
import os
load_dotenv()
import anthropic

client = anthropic.Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

message = client.messages.create(
    model="claude-sonnet-4-6",
    max_tokens=1024,
    messages=[{"role": "user", "content": "Hello, world"}],
)
print(message.content)
# Out:
# [TextBlock(citations=None, text='Hello! 👋 How are you doing? Is there something I can help you with today?', type='text')]

# %%
# wieviele token ich für diese anfrage verbraucht habe
print(message.usage)
# Out:
# Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=10, output_tokens=24, output_tokens_details=None, server_tool_use=None, service_tier='standard')
